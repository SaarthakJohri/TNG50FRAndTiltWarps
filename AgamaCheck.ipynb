# %%
pip install agama
# Out:
# ...
#   Using cached agama-1.00.tar.gz (2.0 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   Getting requirements to build wheel did not run successfully.
#   exit code: 1
#
#   [6 lines of output]
#   Running C:\Users\saart\AppData\Local\Temp\pip-install-oufcm0ye\agama_92bd6644f8d6476c965c21a265f2ea89\setup.py
# ...
#   The system cannot find the path specified.
#   'mv' is not recognized as an internal or external command,
#   operable program or batch file.
#   Exception: Failed to download the package from github
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# ERROR: Failed to build 'agama' when getting requirements to build wheel

# %%
import sys
sys.path.append('C:\\Users\\saart\\Documents\\GitHub\\TNG50FRAndTiltWarps/home/tnguser/python/')
import agama
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import sys
#       2 sys.path.append('C:\\Users\\saart\\Documents\\GitHub\\TNG50FRAndTiltWarps/home/tnguser/python/')
# ----> 3 import agama
#       4 import numpy as np
#
# ModuleNotFoundError: No module named 'agama'
